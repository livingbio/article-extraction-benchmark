# %%
import json
import requests
import html2text
import os

# %%
import urllib.request
from inscriptis import get_text

# %%
def get_content(url):
    api = #gliacloud api
    json_file = requests.get(api + url).json()
    return json_file

# %%
url = "https://venturebeat.com/2019/11/18/new-york-state-attorney-general-investigating-wework-and-former-ceo/"
html = urllib.request.urlopen(url).read().decode('utf-8')

text = get_text(html)
print(text)
# Out:
# Skip to main content
#       * Events
#       * GamesBeat
#       * Jobs
#       * The Customer Experience Summit
#         * Account Settings
#         * Log Out
#         * Become a Member
#         * Sign In
#
#       *
#       *
#
#       VentureBeat
#
#         * AR/VR
#         * Big Data
#         * Cloud
#         * Commerce
#         * DataDecisionMakers
#         * Dev
#         * Enterprise
#         * Entrepreneur
#         * Marketing
#         * Media
#         * Mobile
#         * Security
#         * Social
#         * Transportation
#
#       Follow
#
#       The Machine
#
#         * AI
#         * Machine Learning
#         * Computer Vision
#         * Natural Language Processing
#         * Robotic Process Automation
#
#       Follow
#
#       GamesBeat
#
#         * Games
#         * Esports
#         * PC Gaming
#
#       Follow
#
#       Events
#
#         * Upcoming
#         * Transform
#         * Media Partner
#         * Webinars
#
#       General
#
# ...

# %% [markdown]
# * html -> plain text: html2text.html2text(htmltext)

# %%
for name in p:
    with open(f'./output/{name}', 'r') as in_file:
        data = json.load(in_file)
    for idx in fail_record:
        del data[idx]
    if len(data.keys()) != 145:
        print(f'{name}: error')
    with open(f'./newoutput/{name}', 'w') as out_file:
        json.dump(data, out_file, indent=4, ensure_ascii=False)

# %%
with open(f'./ground-truth.json') as in_file:
    data = json.load(in_file)
for idx in fail_record:
    del data[idx]
if len(data.keys()) != 145:
    print(f'{name}: error')
with open(f'./new-ground-truth.json', 'w') as out_file:
    json.dump(data, out_file, indent=4, ensure_ascii=False)

# %%
with open('./new-ground-truth.json', 'r') as f:
    data = json.load(f)

# %%
for key, value in data.items():
    tmp = get_content(value["url"])
    data[key]['articleBody'] = html2text.html2text(tmp['parsed_content']['content'])
with open(f'./newoutput/glia.json', 'w') as out_file:
    json.dump(data, out_file, indent=4, ensure_ascii=False)

# %%
url = "http://www.panarmenian.net/eng/news/275221/"
api = # gliacloud api
json_file = requests.get(api + url).json

# %%
print(json_file)
# Out:
# <bound method Response.json of <Response [200]>>
